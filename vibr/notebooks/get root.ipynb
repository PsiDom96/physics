# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ditmy\\python_projects\\vibr\\venv\\Scripts'

# %%
# !jupyter --paths
# Out:
# config:
#     C:\Users\ditmy\python_projects\vibr\venv\etc\jupyter
#     C:\Users\ditmy\.jupyter
#     C:\ProgramData\jupyter
# data:
#     C:\Users\ditmy\python_projects\vibr\venv\share\jupyter
#     C:\Users\ditmy\AppData\Roaming\jupyter
#     C:\ProgramData\jupyter
# runtime:
#     C:\Users\ditmy\AppData\Roaming\jupyter\runtime
