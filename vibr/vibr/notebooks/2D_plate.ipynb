# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from vibr.geometry.primitives import create_thin_plate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 4
#       2 import matplotlib.pyplot as plt
#       3 from matplotlib.animation import FuncAnimation
# ----> 4 from vibr.geometry.primitives import create_thin_plate
#
# ModuleNotFoundError: No module named 'vibr'

# %%
# State parameters
radius=1.0              #radius of plate (meters)
resolution=0.01       #grid spacing (meters)

x = np.arange(-radius, radius + resolution, resolution)
y = np.arange(-radius, radius + resolution, resolution)
X, Y = np.meshgrid(x, y)
mask = X**2 + Y**2 <= radius**2

# %%
coords = []
indices = []
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        if mask[i, j]:
            coords.append((X[i, j], Y[i, j]))
            indices.append((i, j))

# %%
plt.plot(coords)

# %%
# Load geometry
domain=create_thin_plate(r)

# %%
# Discretize the domain
mesh = create_mesh(domain)

# %%
# Set up initial condition

# %%
# solve time steps
